# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DBP_df = pd.read_csv('./dataset/DBP.csv')
DGL_df = pd.read_csv('./dataset/DGL.csv')  
DGP_df = pd.read_csv('./dataset/DGP.csv')  
DGZ_df = pd.read_csv('./dataset/DGZ.csv')  
DZZ_df = pd.read_csv('./dataset/DZZ.csv')  
GLD_df = pd.read_csv('./dataset/GLD.csv')  
GLL_df = pd.read_csv('./dataset/GLL.csv')  
IAU_df = pd.read_csv('./dataset/IAU.csv')  
SGOL_df = pd.read_csv('./dataset/SGOL.csv')  
UGL_df = pd.read_csv('./dataset/UGL.csv')

print(len(DBP_df))
print(len(DGL_df))
print(len(DGP_df))
print(len(DGZ_df))
print(len(DZZ_df))
print(len(GLD_df))
print(len(GLL_df))
print(len(IAU_df))
print(len(SGOL_df))
print(len(UGL_df))
# Out:
# 2517
# 2517
# 2517
# 2517
# 2517
# 2517
# 2517
# 2517
# 2517
# 2517

# %%
DBP_df
# Out:
#             Date       Open       High        Low      Close  Volume
# 0     2012-03-30  56.730692  56.876727  56.497030  56.789108   26200
# 1     2012-04-02  56.730688  57.460875  56.691744  57.217480  133200
# 2     2012-04-03  57.266162  57.266162  56.058921  56.166012   40600
# 3     2012-04-04  55.172954  55.211898  54.754316  54.929558   34300
# 4     2012-04-05  55.241110  55.533184  55.241110  55.455296   61300
# ...          ...        ...        ...        ...        ...     ...
# 2512  2022-03-24  52.570000  52.910000  52.389999  52.700001    8300
# 2513  2022-03-25  52.340000  52.639999  52.340000  52.459999    7000
# 2514  2022-03-28  51.810001  52.049999  51.389999  51.400002   15700
# 2515  2022-03-29  50.660000  51.450001  50.509998  51.430000    7800
# 2516  2022-03-30  51.770000  51.869999  51.680000  51.779999    4300
#
# [2517 rows x 6 columns]

# %% [markdown]
# <h1>Create portfolio DF</h1>

# %%
portfolio_df = pd.DataFrame(data = DBP_df['Date'])
portfolio_df['DBP'] = DBP_df['Close']
portfolio_df['DGL'] = DGL_df['Close']
portfolio_df['DGP'] = DGP_df['Close']
portfolio_df['DGZ'] = DGZ_df['Close']
portfolio_df['DZZ'] = DZZ_df['Close']
portfolio_df['GLD'] = GLD_df['Close']
portfolio_df['GLL'] = GLL_df['Close']
portfolio_df['IAU'] = IAU_df['Close']
portfolio_df['SGOL'] = SGOL_df['Close']
portfolio_df['UGL'] = UGL_df['Close']

portfolio_df['Date']= pd.to_datetime(portfolio_df['Date'])

# set index -> data
portfolio_df = portfolio_df.set_index('Date')
portfolio_df
# Out:
#                   DBP        DGL        DGP    DGZ   DZZ         GLD  \
# Date
# 2012-03-30  56.789108  55.779552  53.169998  11.95  4.61  162.119995
# 2012-04-02  57.217480  56.098129  53.689999  11.89  4.57  162.940002
# 2012-04-03  56.166012  55.045868  51.759998  12.12  4.74  159.889999
# 2012-04-04  54.929558  54.032223  49.919998  12.32  4.90  157.210007
# 2012-04-05  55.455296  54.505257  50.669998  12.23  4.82  158.309998
# ...               ...        ...        ...    ...   ...         ...
# 2022-03-24  52.700001  55.950001  44.930000   9.30  2.33  183.130005
# 2022-03-25  52.459999  55.720001  44.520000   9.34  2.36  182.380005
# 2022-03-28  51.400002  54.680000  42.950001   9.52  2.41  179.059998
# 2022-03-29  51.430000  54.740002  43.119999   9.52  2.42  179.139999
# 2022-03-30  51.779999  55.150002  43.700001   9.44  2.39  180.580002
#
#                   GLL        IAU       SGOL        UGL
# Date
# 2012-03-30  67.239998  32.540001  16.523001  88.400002
# 2012-04-02  66.480003  32.680000  16.606001  89.300003
# 2012-04-03  68.879997  32.099998  16.292000  85.959999
# 2012-04-04  71.160004  31.540001  16.020000  82.989998
# 2012-04-05  70.080002  31.760000  16.143999  84.190002
# ...               ...        ...        ...        ...
# 2022-03-24  26.930000  37.290001  18.809999  68.029999
# 2022-03-25  27.150000  37.160000  18.740000  67.430000
# 2022-03-28  28.180000  36.480000  18.400000  64.930000
# 2022-03-29  28.150000  36.500000  18.420000  64.940002
# 2022-03-30  27.709999  36.759998  18.559999  66.019997
#
# [2517 rows x 10 columns]

# %% [markdown]
# <h1>Return Rate of each ETF</h1>

# %%
portfolio_return_rate_df = portfolio_df.pct_change()
portfolio_return_rate_df
# Out:
#                  DBP       DGL       DGP       DGZ       DZZ       GLD  \
# Date
# 2012-03-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2012-04-02  0.007543  0.005711  0.009780 -0.005021 -0.008677  0.005058
# 2012-04-03 -0.018377 -0.018758 -0.035947  0.019344  0.037199 -0.018719
# 2012-04-04 -0.022014 -0.018415 -0.035549  0.016502  0.033755 -0.016761
# 2012-04-05  0.009571  0.008755  0.015024 -0.007305 -0.016327  0.006997
# ...              ...       ...       ...       ...       ...       ...
# 2022-03-24  0.009772  0.007019  0.013306 -0.007471 -0.008511  0.007260
# 2022-03-25 -0.004554 -0.004111 -0.009125  0.004301  0.012876 -0.004095
# 2022-03-28 -0.020206 -0.018665 -0.035265  0.019272  0.021187 -0.018204
# 2022-03-29  0.000584  0.001097  0.003958  0.000000  0.004149  0.000447
# 2022-03-30  0.006805  0.007490  0.013451 -0.008403 -0.012397  0.008038
#
#                  GLL       IAU      SGOL       UGL
# Date
# 2012-03-30       NaN       NaN       NaN       NaN
# 2012-04-02 -0.011303  0.004302  0.005023  0.010181
# 2012-04-03  0.036101 -0.017748 -0.018909 -0.037402
# 2012-04-04  0.033101 -0.017445 -0.016695 -0.034551
# 2012-04-05 -0.015177  0.006975  0.007740  0.014460
# ...              ...       ...       ...       ...
# 2022-03-24 -0.015356  0.008110  0.006959  0.016283
# 2022-03-25  0.008169 -0.003486 -0.003721 -0.008820
# 2022-03-28  0.037937 -0.018299 -0.018143 -0.037075
# 2022-03-29 -0.001065  0.000548  0.001087  0.000154
# 2022-03-30 -0.015631  0.007123  0.007600  0.016631
#
# [2517 rows x 10 columns]

# %% [markdown]
# <h1>Find the best weight</h1>

# %%
portfolio_weight = []
portfolio_returns = []
portfolio_risk = []

no_etf = len(portfolio_df.columns)
time = 100000

#Find the portfolio risk
#This the year risk rate, so * 252 (one year has 252 exchange day)
variance_matrix = portfolio_return_rate_df.cov()*252    

individual_asset_returns = portfolio_df.resample('Y').last().pct_change().mean()
individual_asset_returns
# Out:
# DBP     0.005749
# DGL     0.010505
# DGP     0.023840
# DGZ    -0.012446
# DZZ    -0.023064
# GLD     0.021861
# GLL    -0.041577
# IAU     0.023189
# SGOL    0.022775
# UGL     0.013235
# dtype: float64

# %%
for no in range(time):
    if no % 1000 == 0:
        print(no)
    weight = np.random.random(no_etf)
    weight = weight/np.sum(weight)
    portfolio_weight.append(weight)

    return_rate = np.dot(weight, individual_asset_returns)
    portfolio_returns.append(return_rate)

    #Find the portfolio variance
    var = variance_matrix.mul(weight, axis=0).mul(weight, axis=1).sum().sum()
    #Find the portfolio risk (volatility)
    risk = np.sqrt(var)

    year_risk = risk*np.sqrt(252)
    portfolio_risk.append(year_risk)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000

# %%
print(len(portfolio_returns))
print(len(portfolio_risk))
print(len(portfolio_weight))
# Out:
# 100000
# 100000
# 100000

# %%
data = {'Return Rate': portfolio_returns, 'Risk':portfolio_risk}

for counter, symbol in enumerate(portfolio_df.columns.tolist()):
    data[symbol + ' weight'] = [weight[counter] for weight in portfolio_weight]

compare_portfolios_df = pd.DataFrame(data)
compare_portfolios_df
# Out:
#        Return Rate      Risk  DBP weight  DGL weight  DGP weight  DGZ weight  \
# 0         0.015957  2.731470    0.111331    0.149816    0.094111    0.037031
# 1        -0.000656  0.730655    0.119491    0.103925    0.140451    0.082042
# 2         0.000814  1.470392    0.108516    0.138846    0.013376    0.062025
# 3        -0.000300  0.873810    0.164591    0.163469    0.118000    0.025264
# 4        -0.000648  0.677149    0.066779    0.153942    0.026565    0.074828
# ...            ...       ...         ...         ...         ...         ...
# 99995     0.000096  1.246518    0.232831    0.043570    0.153536    0.064757
# 99996     0.007990  1.741304    0.152717    0.206904    0.141916    0.078637
# 99997     0.011875  2.312441    0.035770    0.189646    0.053022    0.059798
# 99998     0.007197  1.679570    0.123436    0.133633    0.077246    0.078469
# 99999     0.008222  1.654207    0.094438    0.019742    0.140303    0.004506
#
#        DZZ weight  GLD weight  GLL weight  IAU weight  SGOL weight  UGL weight
# 0        0.004921    0.109772    0.019018    0.229473     0.199973    0.044554
# 1        0.145220    0.149600    0.152257    0.006993     0.016928    0.083093
# 2        0.214211    0.023012    0.093884    0.232862     0.065670    0.047599
# 3        0.160808    0.014731    0.144298    0.008129     0.113103    0.087607
# 4        0.170900    0.105108    0.148110    0.075401     0.140633    0.037733
# ...           ...         ...         ...         ...          ...         ...
# 99995    0.028653    0.009697    0.219202    0.132794     0.042678    0.072283
# 99996    0.013828    0.134050    0.096269    0.083364     0.080689    0.011626
# 99997    0.017478    0.185146    0.057133    0.188503     0.072466    0.141039
# 99998    0.087254    0.124374    0.055887    0.063126     0.102334    0.154241
# 99999    0.140060    0.148277    0.088147    0.165070     0.143510    0.055946
#
# [100000 rows x 12 columns]

# %%
compare_portfolios_df.plot.scatter(x='Risk', y='Return Rate', marker='o')

plt.xlabel("Risk")
plt.ylabel("Expected Return")
# Out:
# Text(0, 0.5, 'Expected Return')

# %% [markdown]
# <h1>Minimum Risk</h1>

# %%
min_risk_portfolio = compare_portfolios_df.iloc[compare_portfolios_df['Risk'].idxmin()]
min_risk_portfolio
# Out:
# Return Rate   -0.003309
# Risk           0.198392
# DBP weight     0.031441
# DGL weight     0.240461
# DGP weight     0.029166
# DGZ weight     0.113117
# DZZ weight     0.002754
# GLD weight     0.112642
# GLL weight     0.281414
# IAU weight     0.000748
# SGOL weight    0.156112
# UGL weight     0.032146
# Name: 1659, dtype: float64

# %% [markdown]
# <h1>Highest Sharpe Ratio</h1>

# %%
highest_return_portfolio = compare_portfolios_df.iloc[compare_portfolios_df['Return Rate'].idxmax()]
highest_return_portfolio
# Out:
# Return Rate    0.019702
# Risk           3.603294
# DBP weight     0.112357
# DGL weight     0.035497
# DGP weight     0.228388
# DGZ weight     0.005915
# DZZ weight     0.004244
# GLD weight     0.019288
# GLL weight     0.000313
# IAU weight     0.323710
# SGOL weight    0.200970
# UGL weight     0.069317
# Name: 3677, dtype: float64

# %% [markdown]
# <h1>Highest Return rate</h1>

# %%
risk_free_rate = 0.01

highest_sharpe_portfolio = compare_portfolios_df.iloc[compare_portfolios_df['Return Rate'] .idxmin()]
highest_sharpe_portfolio

# %%
compare_portfolios_df.plot.scatter(x='Risk', y='Return Rate', marker='o')

plt.scatter(min_risk_portfolio[1], min_risk_portfolio[0], color='r')
plt.scatter(highest_sharpe_portfolio[1], highest_sharpe_portfolio[0], color='b')
plt.scatter(highest_return_portfolio[1], highest_return_portfolio[0], color='r', marker='*', s=500)
plt.xlabel("Risk")
plt.ylabel("Expected Return")
# Out:
# Text(0, 0.5, 'Expected Return')
